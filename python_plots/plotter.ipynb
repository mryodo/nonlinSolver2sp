# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D;
import matplotlib.cm as cm;
import math;
import plotly.plotly as py
import numpy as np
from plotly.graph_objs import *
import plotly
plotly.offline.init_notebook_mode()

d12=np.linspace(0, 0.001, 100)
sm2=np.linspace(0, 0.2, 100)
N1d1=np.loadtxt('N1cctoD1.txt', delimiter=',')
N1d2=np.loadtxt('N1cctoD2.txt', delimiter=',')

for i in range(N1d1.shape[0]):
    for j in range(N1d1.shape[1]):
        if math.isnan(N1d1[i][j]):
            N1d1[i][j]=N1d1[i][j+1]
        if N1d1[i][j]<0:
            N1d1[i][j]=1e-5

Z=np.divide(N1d2, N1d1)

data = [
    Surface(
        x=d12, y=sm2, z=Z
    )
]
layout = Layout(
    title='Mt Bruno Elevation',
    autosize=False,
    width=500,
    height=500,
    margin=dict(
        l=65,
        r=50,
        b=65,
        t=90
    )
)

#plotly.ylim((-250,250))
fig = Figure(data=data, layout=layout)
#plotly.offline.iplot(fig, filename='elevations-3d-surface')

plotly.offline.iplot([
    dict(z=Z, type='surface')],
    filename='multiple-surfaces')
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
# <div id="d0ee629e-478c-4093-9b11-aae77488816f" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d0ee629e-478c-4093-9b11-aae77488816f", [{"z": [[null, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518], [null, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080238191360518, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0080746908907392, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.0081255677803573, 1.008125567780 ...

# %%
N1=mp.loadtxt('N1cctoD1.txt', delimiter=',')
print(N1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-21dcf4ff59d5> in <module>()
# ----> 1 N1=mp.loadtxt('N1cctoD1.txt', delimiter=',')
#       2 print(N1)
#
# NameError: name 'mp' is not defined

# %%
for i in range(N1.shape[0]):
    for j in range(N1.shape[1]):
        N1[i][j]=0;
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a4f1a2648def> in <module>()
# ----> 1 for i in range(N1.shape[0]):
#       2     for j in range(N1.shape[1]):
#       3         N1[i][j]=0;
#
# NameError: name 'N1' is not defined

# %%
N1.shape[0]
# Out:
# 100
