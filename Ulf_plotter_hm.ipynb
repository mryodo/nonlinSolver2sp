# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
import numpy as np
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import math

# %%
d12=np.linspace(0, 0.15, 100)
sm2=np.linspace(0, 0.15, 100)
N1=np.loadtxt('N1hmD1_08.txt', delimiter=',')
N2=np.loadtxt('N2hmD1_08.txt', delimiter=',')

for i in range(N1.shape[0]):
    for j in range(N1.shape[1]):
        if math.isnan(N1[i][j]):
            N1[i][j]=N1[i][j+1]
        if N1[i][j]<0:
            N1[i][j]=1e-5

for i in range(N2.shape[0]):
    for j in range(N2.shape[1]):
        if math.isnan(N2[i][j]):
            N2[i][j]=N2[i][j+1]
        if N2[i][j]<0:
            N2[i][j]=1e-5
N1=N1.T
N2=N2.T
#N1=np.flipud(N1)
#N2=np.flipud(N2)   
            
plt.figure(figsize=(10, 10))
cmap = plt.cm.get_cmap("Blues_r")
sf1=plt.contourf(d12,sm2,N1,25,cmap=cmap, alpha=1, origin='lower')
fig.colorbar(im)
cmap = plt.cm.get_cmap("Reds_r")
sf2=plt.contourf(d12,sm2,N2,100,cmap=cmap, alpha=0.6, origin='lower')


plt.show()

# %%
d12=np.linspace(0, 0.001, 100)
sm2=np.linspace(0, 0.2, 100)
N1=np.loadtxt('N1hmD2_04.txt', delimiter=',')
N2=np.loadtxt('N2hmD2_04.txt', delimiter=',')

for i in range(N1.shape[0]):
    for j in range(N1.shape[1]):
        if math.isnan(N1[i][j]):
            N1[i][j]=N1[i][j+1]
        if N1[i][j]<0:
            N1[i][j]=1e-5

for i in range(N2.shape[0]):
    for j in range(N2.shape[1]):
        if math.isnan(N2[i][j]):
            N2[i][j]=N2[i][j+1]
        if N2[i][j]<0:
            N2[i][j]=1e-5
N1=N1.T
N2=N2.T
#N1=np.flipud(N1)
#N2=np.flipud(N2)   
            
plt.figure(figsize=(10, 10))
cmap = plt.cm.get_cmap("Blues_r")
plt.contourf(d12,sm2,N1,25,cmap=cmap, origin='lower')
cmap = plt.cm.get_cmap("Reds_r")
plt.contourf(d12,sm2,N2,100,cmap=cmap, alpha=0.6, origin='lower')


plt.show()

# %%
d12=np.linspace(0, 0.001, 100)
sm2=np.linspace(0, 0.2, 100)
N1=np.loadtxt('N1hmD3_08.txt', delimiter=',')
N2=np.loadtxt('N2hmD3_08.txt', delimiter=',')

for i in range(N1.shape[0]):
    for j in range(N1.shape[1]):
        if math.isnan(N1[i][j]):
            N1[i][j]=N1[i][j+1]
        if N1[i][j]<0:
            N1[i][j]=1e-5

for i in range(N2.shape[0]):
    for j in range(N2.shape[1]):
        if math.isnan(N2[i][j]):
            N2[i][j]=N2[i][j+1]
        if N2[i][j]<0:
            N2[i][j]=1e-5
#N1=N1.T
#N2=N2.T
#N1=np.flipud(N1)
#N2=np.flipud(N2)   
            
plt.figure(figsize=(10, 10))
cmap = plt.cm.get_cmap("Blues_r")
plt.contourf(d12,sm2,N1,25,cmap=cmap, alpha=0.6, origin='lower')
cmap = plt.cm.get_cmap("Reds_r")
plt.contourf(d12,sm2,N2,100,cmap=cmap, alpha=0.6, origin='lower')


plt.show()
